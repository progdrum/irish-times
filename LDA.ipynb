# %% [markdown]
# # LDA
# Gonna try something a little different here from some of the things that I've attempted before. Gonna try some LDA with the `gensim` package and see what sorts of interesting things we can find out. Maybe this could be a back-door way into predicting topics.

# %%
import pandas as pd

df = pd.read_csv('data/irishtimes-date-text.csv')
df.head()
# Out:
#    publish_date headline_category  \
# 0      19960102          business
# 1      19960102          business
# 2      19960102          business
# 3      19960102          business
# 4      19960102          business
#
#                                        headline_text
# 0  Smurfit's share price in retreat despite recor...
# 1        Jamont plans £5m investment to update plant
# 2     Management is blamed for most company failures
# 3  Forte expected to announce a special dividend ...
# 4                Accountancy firm adopts name change

# %%
df.dropna(axis='index', how='any', inplace=True)
df['simple_category'] = df.headline_category.str.split('.').str.get(0)
df['headline_text'] = df['headline_text'].str.lower()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

# corpora_path = '/media/sean/634d9e6c-0d5c-4a60-aa43-9d19a276b10a/nltk_data'
# nltk.data.path.append(corpora_path)

nltk.data.find('corpora/wordnet')
nltk.data.find('corpora/stopwords')
stops = set(stopwords.words('english'))
tokenizer = RegexpTokenizer(r'\w+')
lemmatizer = WordNetLemmatizer()

def clean_headlines(headline):
    tokens = tokenizer.tokenize(headline)
    return [lemmatizer.lemmatize(token) for token in tokens if token not in stops]

df['headline_text'] = df['headline_text'].apply(clean_headlines)
df.head()
# Out:
#    publish_date headline_category  \
# 0      19960102          business
# 1      19960102          business
# 2      19960102          business
# 3      19960102          business
# 4      19960102          business
#
#                                        headline_text simple_category
# 0  [smurfit, share, price, retreat, despite, reco...        business
# 1      [jamont, plan, 5m, investment, update, plant]        business
# 2             [management, blamed, company, failure]        business
# 3  [forte, expected, announce, special, dividend,...        business
# 4          [accountancy, firm, adopts, name, change]        business

# %%
from gensim import corpora
from gensim.models.ldamulticore import LdaMulticore

texts = df['headline_text'].tolist()
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(txt) for txt in texts]
lda = LdaMulticore(corpus, id2word=dictionary, num_topics=6, workers=16)
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
lda.print_topics(num_words=5)
# Out:
# [(0,
#   '0.008*"one" + 0.007*"say" + 0.006*"get" + 0.005*"irish" + 0.005*"health"'),
#  (1, '0.007*"000" + 0.007*"short" + 0.007*"1" + 0.006*"pay" + 0.006*"job"'),
#  (2, '0.019*"man" + 0.010*"year" + 0.009*"dublin" + 0.007*"go" + 0.007*"two"'),
#  (3,
#   '0.010*"time" + 0.010*"irish" + 0.009*"back" + 0.008*"first" + 0.008*"right"'),
#  (4,
#   '0.012*"new" + 0.008*"irish" + 0.008*"ireland" + 0.008*"say" + 0.008*"review"'),
#  (5, '0.009*"u" + 0.007*"ireland" + 0.006*"say" + 0.006*"eu" + 0.006*"new"')]

# %%
import pyLDAvis as ldavis
import pyLDAvis.gensim as ldgensim

lda_display = ldgensim.prepare(lda, corpus, dictionary, sort_topics=False)
ldavis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el128301403994779342888393633328"></div>
# <script type="text/javascript">
#
# var ldavis_el128301403994779342888393633328_data = {"mdsDat": {"x": [0.06157252190524973, 0.016598574577326036, -0.21686772323425363, 0.0033494791752374446, 0.023953854717074563, 0.11139329285936586], "y": [-0.07550582061170123, -0.08795024686472872, -0.03760521407919628, 0.2069926639373476, 0.023776754295008005, -0.029708136676729446], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [15.029424667358398, 17.151519775390625, 17.561418533325195, 15.415337562561035, 15.749667167663574, 19.092636108398438]}, "tinfo": {"Term": ["man", "time", "right", "short", "first", "one", "hit", "review", "1", "diary", "back", "world", "000", "year", "irishman", "three", "health", "warns", "go", "profit", "rise", "death", "irish", "garda\u00ed", "ireland", "job", "crash", "trump", "killed", "murder", "vodafone", "picnic", "cardiff", "cullinan", "aidan", "punchestown", "ipo", "samsung", "lennon", "yemen", "hacking", "nokia", "cyber", "gerrard", "tipp", "lawsuit", "phil", "thornley", "appearance", "forthcoming", "mcnamara", "catalonia", "oliver", "ali", "arrangement", "affordable", "album", "clever", "ibrahim", "playoff", "trump", "sam", "bin", "healthcare", "moyes", "eircom", "fiction", "became", "device", "terry", "morning", "becoming", "iphone", "gerry", "education", "watchdog", "christmas", "everything", "apple", "transfer", "t\u00e1naiste", "u2", "warns", "fixture", "independence", "health", "one", "six", "quiz", "getting", "benefit", "special", "business", "cross", "golf", "nation", "referendum", "release", "power", "china", "abortion", "ira", "card", "red", "medical", "food", "good", "get", "plan", "say", "early", "year", "irish", "new", "london", "win", "life", "change", "state", "make", "report", "court", "job", "cork", "child", "cut", "claim", "sale", "online", "cowen", "2016", "cameron", "digest", "leo", "cycling", "rodgers", "cso", "donal", "gordon", "katie", "atlantic", "downturn", "osprey", "redknapp", "boosted", "colm", "luke", "default", "ar", "2002", "blatter", "pharma", "staunton", "gara", "etc", "operate", "airbus", "pearse", "lisbon", "briefing", "shane", "deutsche", "momentum", "costa", "create", "short", "oecd", "homelessness", "tech", "scrap", "premier", "nature", "vehicle", "luas", "tool", "remembering", "1", "alcohol", "billion", "meeting", "closer", "thinking", "book", "reader", "2013", "2m", "housing", "church", "eye", "check", "na", "step", "pay", "film", "rt\u00e9", "rate", "job", "5m", "2", "interest", "000", "st", "5", "fund", "cut", "martin", "league", "buy", "hospital", "firm", "state", "deal", "may", "say", "top", "irish", "u", "bank", "drug", "dublin", "fall", "rise", "government", "plan", "take", "home", "city", "garda\u00ed", "martyn", "miriam", "mcilroy", "sharon", "robbie", "gatland", "weld", "crunch", "hull", "mercedes", "joseph", "migration", "sachs", "thumb", "toulon", "audi", "pep", "relishing", "flannery", "150m", "bombardier", "cctv", "dj", "leaked", "fitting", "honda", "rae", "villiers", "nominated", "croke", "bmw", "nadal", "overnight", "gael", "goldman", "barrel", "trolley", "cody", "charged", "correction", "jazz", "lifeline", "wounded", "clarification", "shooting", "arrested", "assault", "stabbing", "investigate", "inquest", "man", "monaghan", "leg", "bomb", "three", "sentence", "hand", "oil", "crash", "fine", "murder", "rape", "held", "police", "sex", "jury", "death", "go", "garda", "kill", "shot", "year", "two", "girl", "house", "abuse", "co", "dublin", "killed", "road", "car", "attack", "appeal", "tax", "dy", "woman", "court", "000", "face", "case", "may", "new", "home", "enda", "sexton", "boi", "laden", "sony", "theresa", "mahon", "q", "toyota", "ray", "aisling", "thailand", "inequality", "mcgregor", "jamie", "lawlor", "una", "angela", "stoke", "jose", "kearney", "dave", "yahoo", "berkeley", "heaslip", "rb", "reaching", "hague", "focused", "damascus", "immigration", "2008", "bounce", "slowdown", "whole", "google", "facebook", "twitter", "hungary", "leopardstown", "gaza", "r ...

# %% [markdown]
# Given the prevalence of 'Ireland' words in each of the topics ('irish', 'ireland', 'dublin', 'irishman'), I'm going to treat these as stop words and remove them from the headlines before running the analysis again.

# %%
import multiprocessing

def remove_ireland_words(headline_lst):
    return [word for word in headline_lst if word not in ('irish', 'ireland', 'dublin', 'irishman', 'u')]

df['headline_text'] = df['headline_text'].apply(remove_ireland_words)

texts = df['headline_text'].tolist()
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(txt) for txt in texts]
lda2 = LdaMulticore(corpus, id2word=dictionary, num_topics=6, workers=multiprocessing.cpu_count())

# %%
lda2.print_topics(num_words=5)
# Out:
# [(0,
#   '0.009*"short" + 0.006*"life" + 0.006*"man" + 0.005*"game" + 0.005*"trial"'),
#  (1, '0.011*"new" + 0.007*"uk" + 0.006*"job" + 0.006*"court" + 0.005*"get"'),
#  (2,
#   '0.015*"man" + 0.011*"year" + 0.008*"000" + 0.008*"child" + 0.008*"world"'),
#  (3,
#   '0.008*"new" + 0.007*"report" + 0.007*"market" + 0.006*"say" + 0.006*"go"'),
#  (4,
#   '0.011*"time" + 0.006*"take" + 0.005*"road" + 0.005*"back" + 0.005*"week"'),
#  (5,
#   '0.011*"say" + 0.006*"review" + 0.005*"eu" + 0.005*"price" + 0.005*"talk"')]

# %%
lda_display2 = ldgensim.prepare(lda2, corpus, dictionary, sort_topics=False)
ldavis.display(lda_display2)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el128301403950130870569306231042"></div>
# <script type="text/javascript">
#
# var ldavis_el128301403950130870569306231042_data = {"mdsDat": {"x": [0.1335093631001764, -0.048037948422105646, 0.13752274942839732, -0.06736801135581888, -0.02838652776288152, -0.12723962498776764], "y": [0.036956302820196754, -0.20418845198490662, -0.002910032463037063, 0.07398588599353605, 0.029099360299143427, 0.06705693533506726], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [14.66075325012207, 16.177053451538086, 17.68581199645996, 16.895666122436523, 16.77235984802246, 17.80835723876953]}, "tinfo": {"Term": ["man", "short", "time", "uk", "child", "market", "diary", "world", "report", "year", "charge", "go", "home", "road", "euro", "health", "held", "garda", "000", "game", "review", "life", "job", "final", "price", "trial", "garda\u00ed", "murder", "week", "come", "hike", "ronaldo", "rodgers", "briefing", "4bn", "q", "gordon", "mahon", "mcgregor", "harte", "yemen", "fulham", "pac", "paperback", "baltimore", "maria", "hsbc", "miche\u00e1l", "patronage", "ubs", "relishing", "brom", "copyright", "dj", "hara", "concussion", "playoff", "harding", "robust", "byelection", "short", "gael", "doping", "became", "dunne", "label", "obama", "gerrard", "stick", "haiti", "portrait", "innovation", "wenger", "ar", "literary", "kenny", "berlusconi", "bike", "journalist", "murdered", "fine", "putin", "mayo", "denis", "completes", "correction", "horse", "game", "clarification", "trial", "hearing", "tell", "writer", "migrant", "story", "support", "martin", "life", "protester", "away", "street", "abortion", "political", "award", "mother", "party", "love", "murder", "call", "join", "work", "plan", "man", "dy", "issue", "belfast", "death", "talk", "claim", "new", "get", "year", "court", "cameron", "website", "digest", "andy", "se\u00e1n", "bailout", "leo", "laden", "cullinan", "donal", "ntma", "lawlor", "aidan", "online", "bush", "aviva", "downturn", "jamie", "innovator", "redknapp", "osprey", "cab", "boosted", "8bn", "forthcoming", "hull", "ranelagh", "stride", "d\u00fan", "rowing", "d\u00e1il", "allowance", "twitter", "television", "johnny", "qaeda", "conor", "quiz", "turner", "pop", "manufacturing", "skin", "check", "emission", "create", "rock", "root", "golden", "uk", "festival", "technology", "ross", "watchdog", "chris", "john", "david", "positive", "retail", "al", "teacher", "track", "loss", "job", "tech", "people", "co", "quinn", "boost", "firm", "new", "contract", "court", "pay", "high", "open", "deal", "challenge", "business", "get", "good", "go", "police", "group", "cork", "day", "service", "galway", "show", "eu", "lisbon", "2015", "2014", "schmidt", "corrib", "google", "picnic", "sexton", "homelessness", "chicken", "preview", "strange", "katie", "goldman", "thailand", "bmw", "gdp", "6bn", "stoke", "rb", "thumb", "billionaire", "sachs", "loved", "immigration", "athletics", "heaslip", "catalonia", "r\u00f3is\u00edn", "flannery", "weekly", "2012", "jazz", "ingle", "diary", "assault", "jailed", "garda\u00ed", "beautiful", "held", "seeker", "seizure", "sex", "shoulder", "charge", "irishwoman", "garda", "asylum", "child", "plane", "eye", "world", "abuse", "arrested", "man", "charged", "art", "year", "five", "000", "home", "aid", "men", "shooting", "two", "drug", "inquiry", "care", "quarter", "woman", "body", "murder", "cup", "bank", "may", "say", "call", "profit", "new", "death", "miriam", "omagh", "boi", "scan", "punchestown", "serbia", "cso", "2008", "donohoe", "gatland", "venezuela", "moriarty", "buckley", "phil", "temperature", "obesity", "volvo", "repossession", "berkeley", "danny", "2006", "nfl", "osborne", "elliott", "maiden", "artwork", "strauss", "barca", "collusion", "cctv", "rt\u00e9", "sarkozy", "sharon", "tesco", "con", "liverpool", "alcohol", "promise", "burning", "tribunal", "cancer", "facebook", "pick", "euro", "rugby", "news", "imf", "medical", "control", "health", "classical", "really", "pack", "market", "visit", "answer", "different", "opinion", "zone", "church", "bad", "view", "china", "mental",  ...
